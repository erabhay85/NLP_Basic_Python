# %% [markdown]
# # Ex1: perform sentence tokenization

# %%
from nltk.tokenize import sent_tokenize
import pandas as pd

# %%
data = pd.read_csv('NLP_Q1.csv')

# %%
##data = pd.read_table('NLP_Q3_Q4.txt',header=None,names='C')

# %%
data
# Out:
#                                              Comment
# 0  "Hello there, how are you? Weather is awesome....
# 1  "Hello Mr. Raja, how are you? Weather is aweso...
# 2  "Hello Mr. Raja, how are you. Weather is bad. ...
# 3  "NLP is great technique. It is nice to learn t...
# 4  "AI is making difference in this world now.  I...

# %%
data.shape
# Out:
# (5, 1)

# %%
data['Comment'][0]
SentenceArray = []

# %%
X=0
while X < 5:
    sentence = sent_tokenize(data['Comment'][X])
    SentenceArray.append(sentence)
    X +=1

# %%
SentenceArray
# Out:
# [['"Hello there, how are you?',
#   'Weather is awesome.',
#   'Its raining here now."'],
#  ['"Hello Mr. Raja, how are you?',
#   'Weather is awesome.',
#   'Its raining here now."'],
#  ['"Hello Mr. Raja, how are you.',
#   'Weather is bad.',
#   'Its heavily raining here now."'],
#  ['"NLP is great technique.', 'It is nice to learn this technique."'],
#  ['"AI is making difference in this world now.',
#   'It would be helpful for betterment of human life.',
#   'We need to make advantage of that."']]

# %%
pd.DataFrame(SentenceArray).to_csv('NLP_Q1_Output.csv')

# %% [markdown]
# # Ex2: perform word tokenization

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize("We are learning Artificial Intelligence")
print (words)
# Out:
# ['We', 'are', 'learning', 'Artificial', 'Intelligence']

# %%
X=0
SentenceArray = []
while X < 5:
    sentence = word_tokenize(data['Comment'][X])
    SentenceArray.append(sentence)
    X +=1

# %%
SentenceArray
# Out:
# [['``',
#   'Hello',
#   'there',
#   ',',
#   'how',
#   'are',
#   'you',
#   '?',
#   'Weather',
#   'is',
#   'awesome',
#   '.',
#   'Its',
#   'raining',
#   'here',
#   'now',
#   '.',
#   "''"],
#  ['``',
#   'Hello',
#   'Mr.',
#   'Raja',
#   ',',
#   'how',
#   'are',
#   'you',
#   '?',
#   'Weather',
#   'is',
#   'awesome',
#   '.',
#   'Its',
#   'raining',
#   'here',
#   'now',
#   '.',
#   "''"],
#  ['``',
#   'Hello',
#   'Mr.',
#   'Raja',
#   ',',
#   'how',
#   'are',
#   'you',
#   '.',
#   'Weather',
#   'is',
#   'bad',
#   '.',
#   'Its',
#   'heavily',
#   'raining',
#   'here',
#   'now',
#   '.',
#   "''"],
#  ['``',
#   'NLP',
#   'is',
#   'great',
#   'technique',
#   '.',
#   'It',
#   'is',
#   'nice',
#   'to',
#   'learn',
#   'this',
#   'technique',
#   '.',
#   "''"],
#  ['``',
#   'AI',
#   'is',
#   'making',
#   'difference',
#   'in',
#   'this',
#   'world',
#   'now',
#   '.',
#   'It',
#   'would',
#   'be',
#   'helpful',
#   'for',
# ...

# %%
pd.DataFrame(SentenceArray).to_csv('NLP_Q2_Output.csv')

# %% [markdown]
# # EX3 : POS-Tagging

# %%
data = pd.read_table('NLP_Q3_Q4.txt',header=None,names='C')

# %%
from nltk.tokenize import word_tokenize
from nltk.chunk import ne_chunk
from nltk.tag import pos_tag

# %%
len(data)
# Out:
# 5

# %%
X=0
while X < 5:
    sentence += word_tokenize(data['C'][X])
    X +=1

# %%
print (sentence)
pos_words = pos_tag(sentence)
print ''
print (pos_words)
chunk_sentence = ne_chunk(pos_words)
# Out:
# ['``', 'AI', 'is', 'making', 'difference', 'in', 'this', 'world', 'now', '.', 'It', 'would', 'be', 'helpful', 'for', 'betterment', 'of', 'human', 'life', '.', 'We', 'need', 'to', 'make', 'advantage', 'of', 'that', '.', "''", 'Hello', 'there', ',', 'how', 'are', 'you', '?', 'Weather', 'is', 'awesome', '.', 'Its', 'raining', 'here', 'now', '.', 'Hello', 'Mr.', 'Raja', ',', 'how', 'are', 'you', '?', 'Weather', 'is', 'awesome', '.', 'Its', 'raining', 'here', 'now', '.', 'Hello', 'Mr.', 'Raja', ',', 'how', 'are', 'you', '.', 'Weather', 'is', 'bad', '.', 'Its', 'heavily', 'raining', 'here', 'now', '.', 'NLP', 'is', 'great', 'technique', '.', 'It', 'is', 'nice', 'to', 'learn', 'this', 'technique', '.', 'AI', 'is', 'making', 'difference', 'in', 'this', 'world', 'now', '.', 'It', 'would', 'be', 'helpful', 'for', 'betterment', 'of', 'human', 'life', '.', 'We', 'need', 'to', 'make', 'advantage', 'of', 'that', '.', 'Hello', 'there', ',', 'how', 'are', 'you', '?', 'Weather', 'is', 'awesome', '.',
# ...

# %%
print (chunk_sentence)
chunk_sentence.draw()
# Out:
# (S
#   ``/``
#   AI/NNP
#   is/VBZ
#   making/VBG
#   difference/NN
#   in/IN
#   this/DT
#   world/NN
#   now/RB
#   ./.
#   It/PRP
#   would/MD
#   be/VB
#   helpful/JJ
#   for/IN
#   betterment/NN
#   of/IN
#   human/JJ
#   life/NN
#   ./.
#   We/PRP
#   need/VBP
#   to/TO
#   make/VB
#   advantage/NN
#   of/IN
#   that/DT
#   ./.
#   ''/''
#   Hello/NNP
#   there/RB
#   ,/,
#   how/WRB
#   are/VBP
#   you/PRP
#   ?/.
#   Weather/''
#   is/VBZ
#   awesome/JJ
#   ./.
#   Its/PRP$
#   raining/VBG
#   here/RB
#   now/RB
#   ./.
#   (PERSON Hello/NNP Mr./NNP Raja/NNP)
#   ,/,
#   how/WRB
#   are/VBP
#   you/PRP
#   ?/.
#   Weather/''
#   is/VBZ
#   awesome/JJ
#   ./.
#   Its/PRP$
#   raining/VBG
#   here/RB
#   now/RB
#   ./.
#   (PERSON Hello/NNP Mr./NNP Raja/NNP)
#   ,/,
#   how/WRB
#   are/VBP
#   you/PRP
#   ./.
#   Weather/CC
#   is/VBZ
#   bad/JJ
#   ./.
#   Its/PRP$
#   heavily/RB
#   raining/VBG
#   here/RB
#   now/RB
#   ./.
#   (ORGANIZATION NLP/NNP)
#   is/VBZ
#   great/JJ
# ...

# %% [markdown]
# # EX4: Stop Words and Stemming

# %%
from nltk.corpus import stopwords
data = pd.read_table('NLP_Q3_Q4.txt',header=None,names='C')

# %%
X=0
while X < 5:
    sentence += word_tokenize(data['C'][X])
    X +=1

# %%
stop_words = set(stopwords.words('english'))
filtered_sentence = []
for w in sentence:
    if w not in stop_words:
        filtered_sentence.append(w)

# %%
filtered_sentence
# Out:
# ['``',
#  'AI',
#  'making',
#  'difference',
#  'world',
#  '.',
#  'It',
#  'would',
#  'helpful',
#  'betterment',
#  'human',
#  'life',
#  '.',
#  'We',
#  'need',
#  'make',
#  'advantage',
#  '.',
#  "''",
#  'Hello',
#  ',',
#  '?',
#  'Weather',
#  'awesome',
#  '.',
#  'Its',
#  'raining',
#  '.',
#  'Hello',
#  'Mr.',
#  'Raja',
#  ',',
#  '?',
#  'Weather',
#  'awesome',
#  '.',
#  'Its',
#  'raining',
#  '.',
#  'Hello',
#  'Mr.',
#  'Raja',
#  ',',
#  '.',
#  'Weather',
#  'bad',
#  '.',
#  'Its',
#  'heavily',
#  'raining',
#  '.',
#  'NLP',
#  'great',
#  'technique',
#  '.',
#  'It',
#  'nice',
#  'learn',
#  'technique',
#  '.',
#  'AI',
#  'making',
#  'difference',
#  'world',
#  '.',
#  'It',
#  'would',
#  'helpful',
#  'betterment',
#  'human',
#  'life',
#  '.',
#  'We',
#  'need',
#  'make',
#  'advantage',
#  '.',
#  'Hello',
#  ',',
#  '?',
#  'Weather',
#  'awesome',
#  '.',
#  'Its',
#  'raining',
#  '.',
#  'Hello',
#  'Mr.',
#  'Raja',
#  ',',
#  '?',
# ...

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
for word in filtered_sentence:
    print(ps.stem(word))
# Out:
# ``
# AI
# make
# differ
# world
# .
# It
# would
# help
# better
# human
# life
# .
# We
# need
# make
# advantag
# .
# ''
# hello
# ,
# ?
# weather
# awesom
# .
# it
# rain
# .
# hello
# mr.
# raja
# ,
# ?
# weather
# awesom
# .
# it
# rain
# .
# hello
# mr.
# raja
# ,
# .
# weather
# bad
# .
# it
# heavili
# rain
# .
# nlp
# great
# techniqu
# .
# It
# nice
# learn
# techniqu
# .
# AI
# make
# differ
# world
# .
# It
# would
# help
# better
# human
# life
# .
# We
# need
# make
# advantag
# .
# hello
# ,
# ?
# weather
# awesom
# .
# it
# rain
# .
# hello
# mr.
# raja
# ,
# ?
# weather
# awesom
# .
# it
# rain
# .
# hello
# mr.
# raja
# ,
# .
# weather
# bad
# .
# it
# heavili
# rain
# .
# nlp
# great
# techniqu
# .
# It
# nice
# learn
# techniqu
# .
# AI
# make
# differ
# world
# .
# It
# would
# help
# better
# human
# life
# .
# We
# need
# make
# advantag
# .
# hello
# ,
# ?
# weather
# awesom
# .
# it
# rain
# .
# hello
# mr.
# raja
# ,
# ?
# weather
# awesom
# .
# it
# rain
# ...

# %%
from nltk import stem
wn_lemat = stem.WordNetLemmatizer()
for word in filtered_sentence:
    print(wn_lemat.lemmatize(word))
# Out:
# ``
# AI
# making
# difference
# world
# .
# It
# would
# helpful
# betterment
# human
# life
# .
# We
# need
# make
# advantage
# .
# ''
# Hello
# ,
# ?
# Weather
# awesome
# .
# Its
# raining
# .
# Hello
# Mr.
# Raja
# ,
# ?
# Weather
# awesome
# .
# Its
# raining
# .
# Hello
# Mr.
# Raja
# ,
# .
# Weather
# bad
# .
# Its
# heavily
# raining
# .
# NLP
# great
# technique
# .
# It
# nice
# learn
# technique
# .
# AI
# making
# difference
# world
# .
# It
# would
# helpful
# betterment
# human
# life
# .
# We
# need
# make
# advantage
# .
# Hello
# ,
# ?
# Weather
# awesome
# .
# Its
# raining
# .
# Hello
# Mr.
# Raja
# ,
# ?
# Weather
# awesome
# .
# Its
# raining
# .
# Hello
# Mr.
# Raja
# ,
# .
# Weather
# bad
# .
# Its
# heavily
# raining
# .
# NLP
# great
# technique
# .
# It
# nice
# learn
# technique
# .
# AI
# making
# difference
# world
# .
# It
# would
# helpful
# betterment
# human
# life
# .
# We
# need
# make
# advantage
# .
# Hello
# ,
# ?
# Weather
# awesome
# .
# Its
# ...
